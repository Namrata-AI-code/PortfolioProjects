# %%
import pandas as pd

# %%
heart = pd.read_csv('/content/sample_data/heart.csv')
df = pd.DataFrame(heart)
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
#treat outliers

df[df.Cholesterol>(df.Cholesterol.mean()+3*df.Cholesterol.std())] #checking if this is actually an outlier
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
#check if outlier first then change
df[df.RestingBP>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
df1 = df[df.RestingBP<=(df.RestingBP.mean()+3*df.RestingBP.std())]
df1.shape
# Out:
# (911, 12)

# %%
df2 = df1[df1.Cholesterol<=(df1.Cholesterol.mean()+3*df1.Cholesterol.std())]
df2.shape
# Out:
# (908, 12)

# %%
#do same for other columns you find outliers
df3 = df2[df2.Oldpeak<=(df2.Oldpeak.mean()+3*df2.Oldpeak.std())]
df3.shape
# Out:
# (902, 12)

# %%
dummies = pd.get_dummies(df3,drop_first=True)
dummies = dummies.astype(int)
dummies
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()

# dfle = df3
# dfle.Sex = le.fit_transform(dfle.Sex)
# dfle.ChestPainType = le.fit_transform(dfle.ChestPainType)
# dfle.RestingECG = le.fit_transform(dfle.RestingECG)
# dfle.ExerciseAngina = le.fit_transform(dfle.ExerciseAngina)
# dfle.ST_Slope = le.fit_transform(dfle.ST_Slope)
# dfle.head()
# Out:
# /tmp/ipython-input-25-4199902874.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfle.Sex = le.fit_transform(dfle.Sex)
# /tmp/ipython-input-25-4199902874.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfle.ChestPainType = le.fit_transform(dfle.ChestPainType)
# /tmp/ipython-input-25-4199902874.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
X = dummies.drop('HeartDisease',axis = 'columns')
y = dummies.HeartDisease

# %%
#scaling the values
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.42896269,  0.46089071,  0.85238015, ..., -0.82065181,
#         -1.00221976,  1.13805334],
#        [-0.47545956,  1.5925728 , -0.16132855, ..., -0.82065181,
#          0.99778516, -0.87869344],
#        [-1.74679706, -0.10495034,  0.79657967, ..., -0.82065181,
#         -1.00221976,  1.13805334],
#        ...,
#        [ 0.37209878, -0.10495034, -0.61703246, ...,  1.21854359,
#          0.99778516, -0.87869344],
#        [ 0.37209878, -0.10495034,  0.35947592, ..., -0.82065181,
#          0.99778516, -0.87869344],
#        [-1.64085227,  0.3477225 , -0.20782894, ..., -0.82065181,
#         -1.00221976,  1.13805334]])

# %%
# searching for best model
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

model_params = {
    'random_forest':{
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators': [1,5,10]
        }
    },
    'svm':{
        'model': svm.SVC(gamma='auto'),
        'params':{
            'C': [1,10,20],
            'kernel' : ['rbf','linear']
        }
    },
    'decision_tree':{
        'model': DecisionTreeClassifier(),
        'params':{
            'criterion' : ['gini', 'entropy', 'log_loss']
        }
    }
    # 'gaussian_nb':{
    #     'model': GaussianNB(),
    #     'params':{

    #     }
    # },
    # 'multinomial_nb':{
    #     'model': MultinomialNB(),
    #     'params':{

    #     }
    # }

}

scores = []

# %%
from sklearn.model_selection import GridSearchCV


for model_name , mp in model_params.items():
  clf = GridSearchCV(mp['model'], mp['params'],cv=5, return_train_score = False)
  clf.fit(X_scaled,y)
  scores.append({'model': model_name, 'best_score':clf.best_score_,'best_params':clf.best_params_})

scores
# Out:
# [{'model': 'random_forest',
#   'best_score': np.float64(0.8015346838551258),
#   'best_params': {'n_estimators': 5}},
#  {'model': 'svm',
#   'best_score': np.float64(0.8281031307550645),
#   'best_params': {'C': 1, 'kernel': 'rbf'}},
#  {'model': 'decision_tree',
#   'best_score': np.float64(0.7482627378759975),
#   'best_params': {'criterion': 'log_loss'}}]

# %%
#hence svm has best score among all

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

X_train,X_test, y_train,y_test = train_test_split(X_scaled,y,test_size =0.2)

# %%
model = SVC(C=1,kernel='rbf')
model.fit(X_train,y_train)
score = model.score(X_test,y_test)
score
# Out:
# 0.850828729281768

# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
from sklearn.decomposition import PCA
pca = PCA(0.999)
X_pca = pca.fit_transform(X_scaled)
X_pca
# Out:
# array([[ 3.08177919, -0.43746391,  0.76693587, ...,  0.29254248,
#          0.05735455, -0.06033144],
#        [ 0.16173842, -1.11025858,  0.79692291, ..., -0.12826773,
#          0.11365222, -0.08686529],
#        [ 1.59048141,  2.15993749,  0.58739506, ...,  0.45417589,
#         -0.64669078, -0.0298428 ],
#        ...,
#        [-1.7887605 , -1.46891125, -0.24236951, ...,  0.08012711,
#          0.17102669,  0.11152571],
#        [ 1.06960238,  0.20786041,  1.84114343, ...,  0.11167949,
#         -0.64361764, -0.1282432 ],
#        [ 2.48305552, -0.49635053, -0.98679611, ..., -0.00528568,
#          0.08145192, -0.01456145]])

# %%
X_train_pca, X_test_pca, y_train,y_test = train_test_split(X_pca, y,test_size=0.2)
model_using_pca = SVC(C=1,kernel='rbf')
model_using_pca.fit(X_train_pca,y_train)
final_score = model.score(X_test_pca,y_test)
final_score

#note: in pca the accuracy is a tradeoff
# Out:
# 0.39226519337016574

# %% [markdown]
# # Bagging

# %%
# using bagging for the svm model above without pca
from sklearn.ensemble import BaggingClassifier
bag_model = BaggingClassifier(
    estimator = SVC(C=1,kernel='rbf'),
    n_estimators = 100,
    max_samples = 0.8,
    oob_score = True,
    random_state = 0
)

bag_model.fit(X_train,y_train)
svm_bag_score = bag_model.score(X_test,y_test)
svm_bag_score
# Out:
# 0.5248618784530387

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()
model2.fit(X_train,y_train)
tree_score = model2.score(X_test,y_test)
tree_score
# Out:
# 0.44751381215469616

# %%
bag_model2 = BaggingClassifier(
    estimator = DecisionTreeClassifier(),
    n_estimators = 100,
    max_samples = 0.8,
    oob_score = True,
    random_state = 0
)

bag_model2.fit(X_train,y_train)
tree_bag_score = bag_model.score(X_test,y_test)
tree_bag_score
# Out:
# 0.5248618784530387
